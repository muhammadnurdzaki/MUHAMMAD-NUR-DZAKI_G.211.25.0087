# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadnurdzaki/MUHAMMAD-NUR-DZAKI_G.211.25.0087/blob/main/sorting_G_211_25_0087.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MUHAMMAD NUR DZAKI_G.11.25.0087
#
#
#
#
#
# 4 METODE SORTING
#
#
#
#
#
# 1.BUBBLE SORTING

# %%
#PSEUDOCODE

#Mulai
#Input data arr
#Ulangi dari i = 0 sampai n-1
#    Ulangi dari j = 0 sampai n-i-1
#        Jika arr[j] > arr[j+1]
#            Tukar arr
#Tampilkan hasil
#Selesai

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
data = [22, 44, 33, 55, 66, 11, 77]
bubble_sort(data)
print("Hasil Bubble Sort:")
print(data)
# Out:
# Hasil Bubble Sort:
# [11, 22, 33, 44, 55, 66, 77]

# %%
#ANALISA KOMPLEKSITAS

#Best Case : O(n)
#Worst Case : O(n²)
#Average Case : O(n²)
#Bubble Sort cocok untuk data kecil karena sederhana, tetapi kurang cepat untuk data besar.

# %% [markdown]
# 2.SELECTION SORT

# %%
#PSEUDOCODE

#Mulai
#Input data
#Cari nilai terkecil
#Tukar dengan posisi awal
#Ulangi sampai selesai
#Tampilkan hasil
#Selesai

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
data = [45, 12, 34, 56, 78]
selection_sort(data)
print("Hasil Selection Sort:")
print(data)
# Out:
# Hasil Selection Sort:
# [12, 34, 45, 56, 78]

# %%
#ANALISA KOMPLEKSITAS

#Best Case : O(n²)
#Worst Case : O(n²)
#Average Case : O(n²)
#Selection Sort lebih hemat pertukaran data dibanding Bubble Sort.

# %% [markdown]
# 3.INSERTION SORT

# %%
#PSEUDOCODE

#Mulai
#Input data
#Ambil data kedua
#Bandingkan dengan sebelumnya
#Geser data jika perlu
#Ulangi sampai selesai
#Tampilkan hasil
#Selesai

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
data = [24, 35, 46, 13, 57]
insertion_sort(data)
print("Hasil Insertion Sort:")
print(data)
# Out:
# Hasil Insertion Sort:
# [13, 24, 35, 46, 57]

# %%
#ANALISA KOMPLEKSITAS

#Best Case : O(n)
#Worst Case : O(n²)
#Average Case : O(n²)
#Insertion Sort cukup baik untuk data yang hampir terurut.

# %% [markdown]
# 4.QUICK SORT

# %%
#PSEUDOCODE

#Mulai
#Pilih pivot
#Pisahkan data kecil dan besar
#Lakukan sorting secara rekursif
#Gabungkan hasil
#Selesai

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    kiri = [x for x in arr if x < pivot]
    tengah = [x for x in arr if x == pivot]
    kanan = [x for x in arr if x > pivot]
    return quick_sort(kiri) + tengah + quick_sort(kanan)
data = [9, 8, 7, 6, 5, 4]
hasil = quick_sort(data)
print("Hasil Quick Sort:")
print(hasil)
# Out:
# Hasil Quick Sort:
# [4, 5, 6, 7, 8, 9]

# %%
#ANALISA KOMPLEKSITAS

#Best Case : O(n log n)
#Worst Case : O(n²)
#Average Case : O(n log n)
#Quick Sort lebih cepat dibanding metode sorting sederhana lainnya.
